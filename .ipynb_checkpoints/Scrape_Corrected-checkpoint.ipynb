# %%
#standard class library imports
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import pymongo
from collections import OrderedDict
import numpy as np
import requests
import json
from config import api_key
from pprint import pprint

# %%
#named entity recognition
import spacy
from spacy import displacy
NER = spacy.load("en_core_web_sm")

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
# Define database and collection
db = client.troubles_db
collection = db.items

# %%
### SCRIPT FOR HTML PAGE SCRAPE ###

def text_cleanup(dfrow):
    death = str(scrapedf[dfrow])
    deathsplitspace = death.split()


    #dateofdeath string established and parsed
    deathindex = deathsplitspace.index(year)
    dateofdeath = []
    for deathsplitspaceindex in range(deathindex+1):
        dateofdeath.append(deathsplitspace[deathsplitspaceindex])
    #???:how to convert 'dateofdeath' from string into datetime
    ##print(dateofdeath)

    #namestring established
    indices = [i for i, s in enumerate(deathsplitspace) if '(' in s]
    namestring = []
    lastname = []
    firstname = []
    namerange = range(deathsplitspaceindex+1,indices[0])
    for namecomps in range(deathsplitspaceindex+1,indices[0]):
        namestring.append(deathsplitspace[namecomps])

    #namestring parsing    
    for namecomp in namestring:
        if namecomp.endswith(",") == True:
            lastnameendvalue = namecomp
            lastnameendindex = namestring.index(lastnameendvalue)
    for lastnameind in range(lastnameendindex+1):
        lastname.append(namestring[lastnameind])

    if lastnameendindex+1 == len(namestring)-1:
        firstname.append(namestring[lastnameendindex+1])
    else:
        for firstnameind in range(lastnameendindex+1,len(namestring)-1):
            firstname.append(namestring[firstnameind])
    lastname = [s.replace(",", "") for s in lastname]
    ##print(lastname)
    ##print(firstname)

    #affiliation established
        #excluding for now

    #'killed by' established
    killedbystartindices = [i for i, s in enumerate(deathsplitspace) if 'Killed' in s]
    killedbyendindices = [i for i, s in enumerate(deathsplitspace) if ')' in s]
    killedbystartindice = killedbystartindices[0]
    killedbyendindice = killedbyendindices[2]
    killedby = []

    for killedbycomps in range(killedbystartindice+2,killedbyendindice):
        killedby.append(deathsplitspace[killedbycomps])

    ##print(killedby)

    #details established
    details = []
    for detailcomp in range(killedbyendindice, len(deathsplitspace)):
        details.append(deathsplitspace[detailcomp])

    ##print(details)
    
    #spacy function to return entity info/create Google Places search string
    listforgoogleplaces = []
    def show_ents(doc):
        if doc.ents:  
            for ent in doc.ents:
                listforgoogleplaces.append(str(ent.text))
    #passing details through NER
    parsed_details = NER(' '.join(details))

    for NamedEntity in parsed_details.ents:
        show_ents(NamedEntity)
        
    #clean list of NER to remove dates and lower case NER's
    listofUpperCaseforgoogleplaces = []
    for nercomps in listforgoogleplaces:
        if nercomps[0].isupper():
            listofUpperCaseforgoogleplaces.append(nercomps)
            

    stringforgoogleplaces = ' '.join(listofUpperCaseforgoogleplaces)
    
    
    #PASS 'stringforgoogleplaces' INTO GOOGLE PLACES API
    
    
    target_city = 'divis street and dover street'
    key = api_key

    target_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={stringforgoogleplaces}&key={key}"

    # run a request using our params dictionary
    response = requests.get(target_url)

    # convert response to json
    places = response.json()

    # Print the json (pretty printed)
    print(json.dumps(places, indent=4, sort_keys=True))


    # Extract latitude and longitude
    lat = places["results"][0]["geometry"]["location"]["lat"]
    lng = places["results"][0]["geometry"]["location"]["lng"]

    # Print the latitude and longitude
    print('''
        City: {0}
        Latitude: {1}
        Longitude: {2}
        '''.format(target_city, lat, lng))
    
    post = {
                'Date of Death': dateofdeath,
                'First Name': firstname,
                'Last Name': lastname,
                'Killed by:': killedby,
                'Details':details
            }

    collection.insert_one(post)

# %%
### WRITE TO MONGODB ###

#define/populate list of year pages of deaths
yearsofdeaths = []
for i in range(1969,2002):
    yearsofdeaths.append(str(i))
    
#loop through all year pages and call scrape function/upload to MONGODB    
for year in yearsofdeaths:
    combinedurl = 'https://cain.ulster.ac.uk/sutton/chron/'+str(year)+'.html'
    tables = pd.read_html(combinedurl)
    df = tables[1]
    scrapedf = df.iloc[:,1]
    for row in range (len(scrapedf)):
        text_cleanup(row)
    print(year + ' has been Uploaded!')
# Out:
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Dungiven",
#                     "short_name": "Dungiven",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Londonderry",
#                     "short_name": "Londonderry",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Causeway Coast and Glens",
#                     "short_name": "Causeway Coast and Glens",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT47",
#                     "short_name": "BT47",
#                     "types": [
#                         "postal_code",
#                         "postal_code_prefix"
#                     ]
#                 }
#             ],
#             "formatted_address": "Dungiven, Londonderry BT47, UK",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 54.93612299999999,
#                         "lng": -6.9051635
#                     },
#                     "southwest": {
#                         "lat": 54.9171115,
#                         "lng": -6.9334739
#                     }
#                 },
#                 "location": {
#                     "lat": 54.9258611,
#                     "lng": -6.921175700000001
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.93612299999999,
#                         "lng": -6.9051635
#                     },
#                     "southwest": {
#                         "lat": 54.9171115,
#                         "lng": -6.9334739
#                     }
#                 }
#             },
#             "place_id": "ChIJv50oDVUNYEgRY_g-2pH4BlU",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "145",
#                     "short_name": "145",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Main Street",
#                     "short_name": "Main St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Dungiven",
#                     "short_name": "Dungiven",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Londonderry",
#                     "short_name": "Londonderry",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Causeway Coast and Glens",
#                     "short_name": "Causeway Coast and Glens",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT47 4LF",
#                     "short_name": "BT47 4LF",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "145 Main St, Dungiven, Londonderry BT47 4LF, UK",
#             "geometry": {
#                 "location": {
#                     "lat": 54.9251022,
#                     "lng": -6.919877
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.92645118029149,
#                         "lng": -6.918528019708498
#                     },
#                     "southwest": {
#                         "lat": 54.9237532197085,
#                         "lng": -6.921225980291502
#                     }
#                 }
#             },
#             "place_id": "ChIJN9vxJcRsYEgRhtKQQFWZQao",
#             "types": [
#                 "establishment",
#                 "point_of_interest",
#                 "school",
#                 "secondary_school"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.9258611
#         Longitude: -6.921175700000001
#
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "34a",
#                     "short_name": "34a",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "William Street",
#                     "short_name": "William St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Londonderry",
#                     "short_name": "Londonderry",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Derry and Strabane",
#                     "short_name": "Derry and Strabane",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT48 6ET",
#                     "short_name": "BT48 6ET",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "34a William St, Londonderry BT48 6ET, UK",
#             "geometry": {
#                 "location": {
#                     "lat": 54.9979422,
#                     "lng": -7.323381500000001
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.99929118029149,
#                         "lng": -7.322032519708499
#                     },
#                     "southwest": {
#                         "lat": 54.99659321970849,
#                         "lng": -7.324730480291502
#                     }
#                 }
#             },
#             "place_id": "ChIJpdFfYoLhX0gRNmnjF4yxsfQ",
#             "types": [
#                 "establishment",
#                 "point_of_interest",
#                 "store"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.9979422
#         Longitude: -7.323381500000001
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Cathedral Road",
#                     "short_name": "Cathedral Rd",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Armagh",
#                     "short_name": "Armagh",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Armagh City, Banbridge and Craigavon",
#                     "short_name": "Armagh City, Banbridge and Craigavon",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Cathedral Rd, Armagh, UK",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 54.3540053,
#                         "lng": -6.655831099999999
#                     },
#                     "southwest": {
#                         "lat": 54.3509906,
#                         "lng": -6.6769234
#                     }
#                 },
#                 "location": {
#                     "lat": 54.35184169999999,
#                     "lng": -6.6662514
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.3540053,
#                         "lng": -6.655831099999999
#                     },
#                     "southwest": {
#                         "lat": 54.3509906,
#                         "lng": -6.6769234
#                     }
#                 }
#             },
#             "place_id": "EhhDYXRoZWRyYWwgUmQsIEFybWFnaCwgVUsiLiosChQKEglpFqabcZNgSBGZ3V8gjzHibxIUChIJjRbLfVWNYEgRSBjJzX1jLrk",
#             "types": [
#                 "route"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.35184169999999
#         Longitude: -6.6662514
#
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Divis Street",
#                     "short_name": "Divis St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT12 4QA",
#                     "short_name": "BT12 4QA",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "Divis St, Belfast BT12 4QA, UK",
#             "geometry": {
#                 "location": {
#                     "lat": 54.6000805,
#                     "lng": -5.942235999999999
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.60142948029151,
#                         "lng": -5.940887019708497
#                     },
#                     "southwest": {
#                         "lat": 54.59873151970851,
#                         "lng": -5.943584980291502
#                     }
#                 }
#             },
#             "place_id": "ChIJBYpLs14IYUgRPz8nQ1ybiIk",
#             "plus_code": {
#                 "compound_code": "J325+24 Belfast, UK",
#                 "global_code": "9C6PJ325+24"
#             },
#             "types": [
#                 "establishment",
#                 "point_of_interest"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.6000805
#         Longitude: -5.942235999999999
#
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Divis Street",
#                     "short_name": "Divis St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Divis St, Belfast, UK",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 54.6010597,
#                         "lng": -5.9356111
#                     },
#                     "southwest": {
#                         "lat": 54.5986638,
#                         "lng": -5.949279799999999
#                     }
#                 },
#                 "location": {
#                     "lat": 54.6002147,
#                     "lng": -5.942106799999999
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.60121073029149,
#                         "lng": -5.9356111
#                     },
#                     "southwest": {
#                         "lat": 54.5985127697085,
#                         "lng": -5.949279799999999
#                     }
#                 }
#             },
#             "partial_match": true,
#             "place_id": "ChIJl4d_yl4IYUgResF5Bj4T_Oo",
#             "types": [
#                 "route"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "Falls Road",
#                     "short_name": "Falls Rd",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Falls Rd, Belfast, UK",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 54.6007051,
#                         "lng": -5.9482284
#                     },
#                     "southwest": {
#                         "lat": 54.5798776,
#                         "lng": -5.9820191
#                     }
#                 },
#                 "location": {
#                     "lat": 54.59145710000001,
#                     "lng": -5.9650097
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.6007051,
#                         "lng": -5.9482284
#                     },
#                     "southwest": {
#                         "lat": 54.5798776,
#                         "lng": -5.9820191
#                     }
#                 }
#             },
#             "partial_match": true,
#             "place_id": "ChIJGb2xeoYIYUgR9yZxmK4DZeY",
#             "types": [
#                 "route"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.6002147
#         Longitude: -5.942106799999999
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Divis Street",
#                     "short_name": "Divis St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT12 4QA",
#                     "short_name": "BT12 4QA",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "Divis St, Belfast BT12 4QA, UK",
#             "geometry": {
#                 "location": {
#                     "lat": 54.6000805,
#                     "lng": -5.942235999999999
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.60142948029151,
#                         "lng": -5.940887019708497
#                     },
#                     "southwest": {
#                         "lat": 54.59873151970851,
#                         "lng": -5.943584980291502
#                     }
#                 }
#             },
#             "place_id": "ChIJBYpLs14IYUgRPz8nQ1ybiIk",
#             "plus_code": {
#                 "compound_code": "J325+24 Belfast, UK",
#                 "global_code": "9C6PJ325+24"
#             },
#             "types": [
#                 "establishment",
#                 "point_of_interest"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.6000805
#         Longitude: -5.942235999999999
#
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Herbert Street",
#                     "short_name": "Herbert St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Herbert St, Belfast, UK",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 54.6141146,
#                         "lng": -5.956568
#                     },
#                     "southwest": {
#                         "lat": 54.6125536,
#                         "lng": -5.960551199999999
#                     }
#                 },
#                 "location": {
#                     "lat": 54.6135483,
#                     "lng": -5.9589854
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.6146830802915,
#                         "lng": -5.956568
#                     },
#                     "southwest": {
#                         "lat": 54.6119851197085,
#                         "lng": -5.960551199999999
#                     }
#                 }
#             },
#             "place_id": "ChIJA1gLkGsIYUgR1WtCnFBjo5g",
#             "types": [
#                 "route"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.6135483
#         Longitude: -5.9589854
#
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Butler Place",
#                     "short_name": "Butler Pl",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT14",
#                     "short_name": "BT14",
#                     "types": [
#                         "postal_code",
#                         "postal_code_prefix"
#                     ]
#                 }
#             ],
#             "formatted_address": "Butler Pl, Belfast BT14, UK",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 54.6146968,
#                         "lng": -5.959837299999999
#                     },
#                     "southwest": {
#                         "lat": 54.6132619,
#                         "lng": -5.960645599999999
#                     }
#                 },
#                 "location": {
#                     "lat": 54.6139023,
#                     "lng": -5.9600154
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.6153283302915,
#                         "lng": -5.958892469708497
#                     },
#                     "southwest": {
#                         "lat": 54.6126303697085,
#                         "lng": -5.961590430291501
#                     }
#                 }
#             },
#             "place_id": "ChIJ2eO6gGwIYUgRR1hiwPxPSh4",
#             "types": [
#                 "route"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.6139023
#         Longitude: -5.9600154
#
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "25",
#                     "short_name": "25",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Bombay Street",
#                     "short_name": "Bombay St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT13 2RX",
#                     "short_name": "BT13 2RX",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "25 Bombay St, Belfast BT13 2RX, UK",
#             "geometry": {
#                 "location": {
#                     "lat": 54.601066,
#                     "lng": -5.957290599999999
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.6024149802915,
#                         "lng": -5.955941619708497
#                     },
#                     "southwest": {
#                         "lat": 54.5997170197085,
#                         "lng": -5.958639580291502
#                     }
#                 }
#             },
#             "place_id": "ChIJ423qADEJYUgRH1sGUEhBF7w",
#             "plus_code": {
#                 "compound_code": "J22V+C3 Belfast, UK",
#                 "global_code": "9C6PJ22V+C3"
#             },
#             "types": [
#                 "establishment",
#                 "museum",
#                 "point_of_interest",
#                 "tourist_attraction"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.601066
#         Longitude: -5.957290599999999
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Palmer Street",
#                     "short_name": "Palmer St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT13 3HZ",
#                     "short_name": "BT13 3HZ",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "Palmer St, Belfast BT13 3HZ, UK",
#             "geometry": {
#                 "location": {
#                     "lat": 54.6098667,
#                     "lng": -5.9608322
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.61121568029149,
#                         "lng": -5.959483219708497
#                     },
#                     "southwest": {
#                         "lat": 54.60851771970849,
#                         "lng": -5.962181180291502
#                     }
#                 }
#             },
#             "place_id": "ChIJ6b0tlW4IYUgRq7GttN6MhKM",
#             "types": [
#                 "establishment",
#                 "food",
#                 "point_of_interest",
#                 "restaurant"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.6098667
#         Longitude: -5.9608322
#
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "23",
#                     "short_name": "23",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Avoca Street",
#                     "short_name": "Avoca St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT14 6EN",
#                     "short_name": "BT14 6EN",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "23 Avoca St, Belfast BT14 6EN, UK",
#             "geometry": {
#                 "location": {
#                     "lat": 54.6117527,
#                     "lng": -5.9447091
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.6131016802915,
#                         "lng": -5.943360119708498
#                     },
#                     "southwest": {
#                         "lat": 54.6104037197085,
#                         "lng": -5.946058080291502
#                     }
#                 }
#             },
#             "place_id": "ChIJ1ZDZA0QIYUgRrQAiiUc8sNc",
#             "plus_code": {
#                 "compound_code": "J364+P4 Belfast, UK",
#                 "global_code": "9C6PJ364+P4"
#             },
#             "types": [
#                 "establishment",
#                 "point_of_interest"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.6117527
#         Longitude: -5.9447091
#
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Shankill Road & Downing Street",
#                     "short_name": "Shankill Rd & Downing St",
#                     "types": [
#                         "intersection"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT13 1JD",
#                     "short_name": "BT13 1JD",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "Shankill Rd & Downing St, Belfast BT13 1JD, UK",
#             "geometry": {
#                 "location": {
#                     "lat": 54.6039432,
#                     "lng": -5.946278200000001
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.60529218029149,
#                         "lng": -5.9449292197085
#                     },
#                     "southwest": {
#                         "lat": 54.6025942197085,
#                         "lng": -5.947627180291503
#                     }
#                 }
#             },
#             "place_id": "Ei5TaGFua2lsbCBSZCAmIERvd25pbmcgU3QsIEJlbGZhc3QgQlQxMyAxSkQsIFVLImYiZAoUChIJza2m_lwIYUgRf868zyQji4QSFAoSCc2tpv5cCGFIEX_OvM8kI4uEGhQKEgmFigkOXQhhSBGB5Pno2NtQkxoUChIJIwJe-1wIYUgRG1nQ8HdrQgYiCg2I5osgFYKrdPw",
#             "types": [
#                 "intersection"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.6039432
#         Longitude: -5.946278200000001
#
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Shankill Road",
#                     "short_name": "Shankill Rd",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT13",
#                     "short_name": "BT13",
#                     "types": [
#                         "postal_code",
#                         "postal_code_prefix"
#                     ]
#                 }
#             ],
#             "formatted_address": "Shankill Rd, Belfast BT13, UK",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 54.60638489999999,
#                         "lng": -5.940115400000001
#                     },
#                     "southwest": {
#                         "lat": 54.6023319,
#                         "lng": -5.96085
#                     }
#                 },
#                 "location": {
#                     "lat": 54.6041683,
#                     "lng": -5.950658
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.60638489999999,
#                         "lng": -5.940115400000001
#                     },
#                     "southwest": {
#                         "lat": 54.6023319,
#                         "lng": -5.96085
#                     }
#                 }
#             },
#             "partial_match": true,
#             "place_id": "ChIJhYoJDl0IYUgRgeT56NjbUJM",
#             "types": [
#                 "route"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.6041683
#         Longitude: -5.950658
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Shankill Road",
#                     "short_name": "Shankill Rd",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT13",
#                     "short_name": "BT13",
#                     "types": [
#                         "postal_code",
#                         "postal_code_prefix"
#                     ]
#                 }
#             ],
#             "formatted_address": "Shankill Rd, Belfast BT13, UK",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 54.60638489999999,
#                         "lng": -5.940115400000001
#                     },
#                     "southwest": {
#                         "lat": 54.6023319,
#                         "lng": -5.96085
#                     }
#                 },
#                 "location": {
#                     "lat": 54.6041683,
#                     "lng": -5.950658
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.60638489999999,
#                         "lng": -5.940115400000001
#                     },
#                     "southwest": {
#                         "lat": 54.6023319,
#                         "lng": -5.96085
#                     }
#                 }
#             },
#             "place_id": "ChIJhYoJDl0IYUgRgeT56NjbUJM",
#             "types": [
#                 "route"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.6041683
#         Longitude: -5.950658
#
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Ballyshannon",
#                     "short_name": "Ballyshannon",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Townparks",
#                     "short_name": "Townparks",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "County Donegal",
#                     "short_name": "DL",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Ireland",
#                     "short_name": "IE",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Townparks, Ballyshannon, Co. Donegal, Ireland",
#             "geometry": {
#                 "location": {
#                     "lat": 54.5029882,
#                     "lng": -8.1920416
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.5094667,
#                         "lng": -8.1760342
#                     },
#                     "southwest": {
#                         "lat": 54.4965087,
#                         "lng": -8.208049
#                     }
#                 }
#             },
#             "place_id": "ChIJNVB7AwP-XkgRYOUxl6nHAAo",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.5029882
#         Longitude: -8.1920416
#
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Library Street",
#                     "short_name": "Library St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT1",
#                     "short_name": "BT1",
#                     "types": [
#                         "postal_code",
#                         "postal_code_prefix"
#                     ]
#                 }
#             ],
#             "formatted_address": "Library St, Belfast BT1, UK",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 54.60406510000001,
#                         "lng": -5.930689999999999
#                     },
#                     "southwest": {
#                         "lat": 54.6028257,
#                         "lng": -5.9341439
#                     }
#                 },
#                 "location": {
#                     "lat": 54.6034385,
#                     "lng": -5.9322862
#                 },
# ...
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT15 3FR",
#                     "short_name": "BT15 3FR",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "Ashfield Cres, Dunmore Park, Belfast BT15 3FR, UK",
#             "geometry": {
#                 "location": {
#                     "lat": 54.6224555,
#                     "lng": -5.935304599999999
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.6238044802915,
#                         "lng": -5.933955619708497
#                     },
#                     "southwest": {
#                         "lat": 54.6211065197085,
#                         "lng": -5.936653580291502
#                     }
#                 }
#             },
#             "place_id": "ChIJ3eRVwTYIYUgRoVBSip0pRxA",
#             "plus_code": {
#                 "compound_code": "J3C7+XV Belfast, UK",
#                 "global_code": "9C6PJ3C7+XV"
#             },
#             "types": [
#                 "establishment",
#                 "point_of_interest"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.6224555
#         Longitude: -5.935304599999999
#
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Glenalina Park",
#                     "short_name": "Glenalina Park",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT12",
#                     "short_name": "BT12",
#                     "types": [
#                         "postal_code",
#                         "postal_code_prefix"
#                     ]
#                 }
#             ],
#             "formatted_address": "Glenalina Park, Belfast BT12, UK",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 54.5950578,
#                         "lng": -5.983778699999999
#                     },
#                     "southwest": {
#                         "lat": 54.5932842,
#                         "lng": -5.9852241
#                     }
#                 },
#                 "location": {
#                     "lat": 54.5939002,
#                     "lng": -5.9849495
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.5955199802915,
#                         "lng": -5.983152419708498
#                     },
#                     "southwest": {
#                         "lat": 54.5928220197085,
#                         "lng": -5.985850380291502
#                     }
#                 }
#             },
#             "partial_match": true,
#             "place_id": "ChIJ1QVxqNQHYUgRRYZcsNNDef4",
#             "types": [
#                 "route"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.5939002
#         Longitude: -5.9849495
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Seaforde Street",
#                     "short_name": "Seaforde St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "BT5",
#                     "short_name": "BT5",
#                     "types": [
#                         "postal_code",
#                         "postal_code_prefix"
#                     ]
#                 }
#             ],
#             "formatted_address": "Seaforde St, Belfast BT5, UK",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 54.5993984,
#                         "lng": -5.906932299999999
#                     },
#                     "southwest": {
#                         "lat": 54.59829329999999,
#                         "lng": -5.9079628
#                     }
#                 },
#                 "location": {
#                     "lat": 54.5986543,
#                     "lng": -5.907423199999999
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.60019483029149,
#                         "lng": -5.906098569708497
#                     },
#                     "southwest": {
#                         "lat": 54.59749686970849,
#                         "lng": -5.908796530291502
#                     }
#                 }
#             },
#             "partial_match": true,
#             "place_id": "ChIJQSkDQagJYUgR9gc2eHmKpLE",
#             "types": [
#                 "route"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "Short Strand",
#                     "short_name": "Short Strand",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Short Strand, Belfast, UK",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 54.60020189999999,
#                         "lng": -5.9102386
#                     },
#                     "southwest": {
#                         "lat": 54.5957129,
#                         "lng": -5.9130128
#                     }
#                 },
#                 "location": {
#                     "lat": 54.598002,
#                     "lng": -5.912484399999999
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.60020189999999,
#                         "lng": -5.9102386
#                     },
#                     "southwest": {
#                         "lat": 54.5957129,
#                         "lng": -5.9130128
#                     }
#                 }
#             },
#             "partial_match": true,
#             "place_id": "ChIJJ7ZN7qkJYUgRSWFjGuv6lZw",
#             "types": [
#                 "route"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.5986543
#         Longitude: -5.907423199999999
#
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Falls Road",
#                     "short_name": "Falls Rd",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Falls Rd, Belfast, UK",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 54.6007051,
#                         "lng": -5.9482284
#                     },
#                     "southwest": {
#                         "lat": 54.5798776,
#                         "lng": -5.9820191
#                     }
#                 },
#                 "location": {
#                     "lat": 54.59145710000001,
#                     "lng": -5.9650097
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.6007051,
#                         "lng": -5.9482284
#                     },
#                     "southwest": {
#                         "lat": 54.5798776,
#                         "lng": -5.9820191
#                     }
#                 }
#             },
#             "partial_match": true,
#             "place_id": "ChIJGb2xeoYIYUgR9yZxmK4DZeY",
#             "types": [
#                 "route"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.59145710000001
#         Longitude: -5.9650097
#
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Falls Road",
#                     "short_name": "Falls Rd",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "postal_town"
#                     ]
#                 },
#                 {
#                     "long_name": "Belfast",
#                     "short_name": "Belfast",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Northern Ireland",
#                     "short_name": "Northern Ireland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United Kingdom",
#                     "short_name": "GB",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Falls Rd, Belfast, UK",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 54.6007051,
#                         "lng": -5.9482284
#                     },
#                     "southwest": {
#                         "lat": 54.5798776,
#                         "lng": -5.9820191
#                     }
#                 },
#                 "location": {
#                     "lat": 54.59145710000001,
#                     "lng": -5.9650097
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 54.6007051,
#                         "lng": -5.9482284
#                     },
#                     "southwest": {
#                         "lat": 54.5798776,
#                         "lng": -5.9820191
#                     }
#                 }
#             },
#             "partial_match": true,
#             "place_id": "ChIJGb2xeoYIYUgR9yZxmK4DZeY",
#             "types": [
#                 "route"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#
#         City: divis street and dover street
#         Latitude: 54.59145710000001
#         Longitude: -5.9650097
# {
#     "results": [],
#     "status": "ZERO_RESULTS"
# }
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-f792801e08a9> in <module>
#      13     scrapedf = df.iloc[:,1]
#      14     for row in range (len(scrapedf)):
# ---> 15         text_cleanup(row)
#      16     print(year + ' has been Uploaded!')
#
# <ipython-input-18-be43abac5b19> in text_cleanup(dfrow)
#     103
#     104     # Extract latitude and longitude
# --> 105     lat = places["results"][0]["geometry"]["location"]["lat"]
#     106     lng = places["results"][0]["geometry"]["location"]["lng"]
#     107
#
# IndexError: list index out of range

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3b75cb2b08d6> in <module>
# ----> 1 print (lat)
#
# NameError: name 'lat' is not defined
